# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv("untitled.csv")

# %%
df.head()
# Out:
#                    review sentiment
# 0  This movie was amazing       pos
# 1      I loved the acting       pos
# 2         Best movie ever       pos
# 3     Fantastic storyline       pos
# 4    Wonderful experience       pos

# %%
ps = PorterStemmer()

# %%
corpus = [ ]
for review in df['review']:
  review = re.sub('[^a-zA-Z]', ' ' , review)
  review = review.lower()
  words = review.split()
  words = [ps.stem(word) for word in words
           if word not in stopwords.words('english')]
  review = ' '.join(words)
  corpus.append(review)

# %%
print("claeaned data " , corpus)
# Out:
# claeaned data  ['movi amaz', 'love act', 'best movi ever', 'fantast storylin', 'wonder experi', 'hate movi', 'worst movi ever', 'bore slow', 'wast time', 'terribl act']

# %%
tfidf = TfidfVectorizer()
x = tfidf.fit_transform(corpus).toarray()
y = df['sentiment'].values.ravel()

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=42 , test_size = 0.2)

# %%
model = MultinomialNB()
model.fit(x_train , y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array(['neg', 'neg'], dtype='<U3')

# %%
acc= accuracy_score(y_test , y_pred)
acc
# Out:
# 0.5

# %%
while True:
  text = input("enter review :  (or exit)")
  if text.lower() == "exit":
    break
  text = re.sub('[^a-zA-Z]', ' ' , text)
  text = text.lower()
  words = text.split()
  words = [ps.stem(word)
         for word in words
         if word not in stopwords.words('english')]
  text = ' '.join(words)
  vector = tfidf.transform([text]).toarray()
  result = model.predict(vector)
  if result[0] == 'pos':
    print("the review is positive")
  else :
    print("the review is negative")
# Out:
# enter review :  (or exit)amazing place
# the review is positive
# enter review :  (or exit)disgusted
# the review is negative
# enter review :  (or exit)exit

# %%
# pip install nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import heapq
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize , sent_tokenize

# %%
text = """High-profile applications of AI include advanced web search engines, chatbots, virtual assistants, autonomous vehicles, and play and analysis in strategy games (e.g., chess and Go). Since the 2020s, generative AI has become widely available to generate images, audio, and videos from text prompts.

The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, and perception, as well as support for robotics.[a] To reach these goals, AI researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.[2] Some companies, such as OpenAI, Google DeepMind and Meta, aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.[3]

Artificial intelligence was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as AI winters.[7][8] Funding and interest increased substantially after 2012, when graphics processing units began being used to accelerate neural networks, and deep learning outperformed previous AI techniques.[9] This growth accelerated further after 2017 with the transformer architecture.[10] In the 2020s, an AI boom has coincided with advances in generative AI, which allowed for the creation and modification of media. In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, and potential existential risks have prompted discussion"""
sentence = sent_tokenize(text)
sentence
# Out:
# ['High-profile applications of AI include advanced web search engines, chatbots, virtual assistants, autonomous vehicles, and play and analysis in strategy games (e.g., chess and Go).',
#  'Since the 2020s, generative AI has become widely available to generate images, audio, and videos from text prompts.',
#  'The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, and perception, as well as support for robotics.',
#  '[a] To reach these goals, AI researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.',
#  '[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.',
#  '[2] Some companies, such as OpenAI, Google DeepMind and Meta, aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.',
#  '[3]\n\nArtificial intelligence was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as AI winters.',
#  '[7][8] Funding and interest increased substantially after 2012, when graphics processing units began being used to accelerate neural networks, and deep learning outperformed previous AI techniques.',
#  '[9] This growth accelerated further after 2017 with the transformer architecture.',
#  '[10] In the 2020s, an AI boom has coincided with advances in generative AI, which allowed for the creation and modification of media.',
#  "In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, and potential existential risks have prompted discussion"]

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
word_frequencies = {}
for word in word_tokenize(text.lower()):
  if word.isalnum() and word not in stop_words:
    word_frequencies[word] = word_frequencies.get(word, 0)+1
word_frequencies
# Out:
# {'applications': 1,
#  'ai': 13,
#  'include': 2,
#  'advanced': 1,
#  'web': 1,
#  'search': 2,
#  'engines': 1,
#  'chatbots': 1,
#  'virtual': 1,
#  'assistants': 1,
#  'autonomous': 1,
#  'vehicles': 1,
#  'play': 1,
#  'analysis': 1,
#  'strategy': 1,
#  'games': 1,
#  'chess': 1,
#  'go': 1,
#  'since': 1,
#  '2020s': 2,
#  'generative': 2,
#  'become': 1,
#  'widely': 1,
#  'available': 1,
#  'generate': 1,
#  'images': 1,
#  'audio': 1,
#  'videos': 1,
#  'text': 1,
#  'prompts': 1,
#  'traditional': 1,
#  'goals': 2,
#  'research': 2,
#  'learning': 2,
#  'reasoning': 1,
#  'knowledge': 1,
#  'representation': 1,
#  'planning': 1,
#  'natural': 1,
#  'language': 1,
#  'processing': 2,
#  'perception': 1,
#  'well': 2,
#  'support': 1,
#  'robotics': 1,
#  'reach': 1,
#  'researchers': 1,
#  'used': 2,
#  'techniques': 2,
#  'including': 1,
#  'state': 1,
#  'space': 1,
#  'mathematical': 1,
#  'optimization': 1,
#  'formal': 1,
#  'logic': 1,
#  'artificial': 3,
#  'neural': 2,
#  'networks': 2,
#  'methods': 1,
#  'based': 1,
#  'statistics': 1,
#  'operations': 1,
#  'economics': 1,
#  'b': 1,
#  'also': 1,
#  'draws': 1,
#  'upon': 1,
#  'psychology': 1,
#  'linguistics': 1,
#  'philosophy': 1,
#  'neuroscience': 1,
#  'fields': 1,
#  '2': 1,
#  'companies': 1,
#  'openai': 1,
#  'google': 1,
#  'deepmind': 1,
#  'meta': 1,
#  'aim': 1,
#  'create': 1,
#  'general': 1,
#  'intelligence': 2,
#  'agi': 1,
#  'complete': 1,
#  'virtually': 1,
#  'cognitive': 1,
#  'task': 1,
#  'least': 1,
#  'human': 1,
#  '3': 1,
#  'founded': 1,
#  'academic': 1,
#  'discipline': 1,
#  '1956': 1,
#  '4': 1,
#  'field': 1,
#  'went': 1,
#  'multiple': 1,
#  'cycles': 1,
#  'optimism': 1,
#  'throughout': 1,
#  'history': 1,
#  '5': 1,
#  '6': 1,
#  'followed': 1,
#  'periods': 1,
#  'disappointment': 1,
#  'loss': 1,
#  'funding': 2,
#  'known': 1,
#  'winters': 1,
#  '7': 1,
#  '8': 1,
#  'interest': 1,
#  'increased': 1,
#  'substantially': 1,
#  '2012': 1,
#  'graphics': 1,
#  'units': 1,
#  'began': 1,
#  'accelerate': 1,
#  'deep': 1,
#  'outperformed': 1,
#  'previous': 1,
#  '9': 1,
#  'growth': 1,
#  'accelerated': 1,
#  '2017': 1,
#  'transformer': 1,
#  'architecture': 1,
#  '10': 1,
#  'boom': 1,
#  'coincided': 1,
#  'advances': 1,
#  'allowed': 1,
#  'creation': 1,
#  'modification': 1,
#  'media': 1,
#  'addition': 1,
#  'safety': 1,
#  'unintended': 1,
#  'consequences': 1,
#  'harms': 1,
#  'use': 1,
#  'ethical': 1,
#  'concerns': 1,
#  'effects': 1,
#  'potential': 1,
#  'existential': 1,
#  'risks': 1,
#  'prompted': 1,
#  'discussion': 1}

# %%
sentence_score = {}
for sentence in sentence:
    for word in word_tokenize(sentence.lower()):
        if word in word_frequencies:
            sentence_score[sentence]= sentence_score.get(sentence, 0)+word_frequencies[word]
sentence_score
# Out:
# {'High-profile applications of AI include advanced web search engines, chatbots, virtual assistants, autonomous vehicles, and play and analysis in strategy games (e.g., chess and Go).': 32,
#  'Since the 2020s, generative AI has become widely available to generate images, audio, and videos from text prompts.': 27,
#  'The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, and perception, as well as support for robotics.': 35,
#  '[a] To reach these goals, AI researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.': 44,
#  '[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.': 22,
#  '[2] Some companies, such as OpenAI, Google DeepMind and Meta, aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.': 36,
#  '[3]\n\nArtificial intelligence was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as AI winters.': 41,
#  '[7][8] Funding and interest increased substantially after 2012, when graphics processing units began being used to accelerate neural networks, and deep learning outperformed previous AI techniques.': 40,
#  '[9] This growth accelerated further after 2017 with the transformer architecture.': 6,
#  '[10] In the 2020s, an AI boom has coincided with advances in generative AI, which allowed for the creation and modification of media.': 38,
#  "In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, and potential existential risks have prompted discussion": 53}

# %%
summary_sentence = heapq.nlargest(3 , sentence_score , key = sentence_score.get)
summary_sentence
# Out:
# ["In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, and potential existential risks have prompted discussion",
#  '[a] To reach these goals, AI researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.',
#  '[3]\n\nArtificial intelligence was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as AI winters.']

# %%
summary = " ".join(summary_sentence)
summary
# Out:
# "In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, and potential existential risks have prompted discussion [a] To reach these goals, AI researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. [3]\n\nArtificial intelligence was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as AI winters."

# %%
print(text)
print(summary)
# Out:
# High-profile applications of AI include advanced web search engines, chatbots, virtual assistants, autonomous vehicles, and play and analysis in strategy games (e.g., chess and Go). Since the 2020s, generative AI has become widely available to generate images, audio, and videos from text prompts.
#
# The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, and perception, as well as support for robotics.[a] To reach these goals, AI researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.[2] Some companies, such as OpenAI, Google DeepMind and Meta, aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.[3]
#
# Artificial intelligence was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as AI winters.[7][8] Funding and interest increased substantially after 2012, when graphics processing units began being used to accelerate neural networks, and deep learning outperformed previous AI techniques.[9] This growth accelerated further after 2017 with the transformer architecture.[10] In the 2020s, an AI boom has coincided with advances in generative AI, which allowed for the creation and modification of media. In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, and potential existential risks have prompted discussion
# In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, and potential existential risks have prompted discussion [a] To reach these goals, AI researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. [3]
#
# Artificial intelligence was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as AI winters.

# %%
simple_words = {"artificial intelligence" : "smart computers" ,
                "transportation" :"travel" ,
                "decision making" : " making decisions",
                "recognizing" :" identifying",
                "automate" : "do itself"}
easy_summary = summary.lower()
for x , y in simple_words.items():
  easy_summary = easy_summary.replace(x , y)
easy_summary
# Out:
# "in addition to ai safety and unintended consequences and harms from the use of ai, ethical concerns, ai's long-term effects, and potential existential risks have prompted discussion [a] to reach these goals, ai researchers have used techniques including state space search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. [3]\n\nsmart computers was founded as an academic discipline in 1956,[4] and the field went through multiple cycles of optimism throughout its history,[5][6] followed by periods of disappointment and loss of funding, known as ai winters."
